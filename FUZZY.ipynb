# %%
A = dict()
B = dict()
Y = dict()

A = {"a": 0.2, "b": 0.3, "c": 0.6, "d": 0.6}
B = {"a": 0.9, "b": 0.9, "c": 0.4, "d": 0.5}

print('The First Fuzzy Set is :', A)
print('The Second Fuzzy Set is :', B)


for A_key, B_key in zip(A, B):
	A_value = A[A_key]
	B_value = B[B_key]

	if A_value > B_value:
		Y[A_key] = A_value
	else:
		Y[B_key] = B_value
print('Fuzzy Set Union is :', Y)

for A_key, B_key in zip(A, B):
    A_value = A[A_key]
    B_value = B[B_key]

    if A_value < B_value:
        Y[A_key] = A_value
    else:
        Y[B_key] = B_value
print('Fuzzy Set Intersection is :', Y)

for A_key in A:
   Y[A_key]= 1-A[A_key]
print('Fuzzy Set Complement is :', Y)

for A_key, B_key in zip(A, B):
    A_value = A[A_key]
    B_value = B[B_key]
    B_value = 1 - B_value

    if A_value < B_value:
        Y[A_key] = A_value
    else:
        Y[B_key] = B_value

print('Fuzzy Set Difference is :', Y)
# Out:
# The First Fuzzy Set is : {'a': 0.2, 'b': 0.3, 'c': 0.6, 'd': 0.6}
# The Second Fuzzy Set is : {'a': 0.9, 'b': 0.9, 'c': 0.4, 'd': 0.5}
# Fuzzy Set Union is : {'a': 0.9, 'b': 0.9, 'c': 0.6, 'd': 0.6}
# Fuzzy Set Intersection is : {'a': 0.2, 'b': 0.3, 'c': 0.4, 'd': 0.5}
# Fuzzy Set Complement is : {'a': 0.8, 'b': 0.7, 'c': 0.4, 'd': 0.4}
# Fuzzy Set Difference is : {'a': 0.09999999999999998, 'b': 0.09999999999999998, 'c': 0.6, 'd': 0.5}

# %%
import random
from fuzzywuzzy import fuzz

class Chatbot:
    def __init__(self):
        self.responses = ["Hello!", "How are you?", "What can I do for you?"]

    def generate_response(self, user_input):
        best_match = None
        best_score = 0
        for response in self.responses:
            score = fuzz.ratio(user_input, response)
            if score > best_score:
                best_match = response
                best_score = score

        return best_match

chatbot = Chatbot()

while True:
    user_input = input("You: ")
    response = chatbot.generate_response(user_input)
    print("Chatbot:", response)
# Out:
# You: hey
# Chatbot: How are you?
# You: good
# Chatbot: How are you?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-78d811d5a98f> in <cell line: 21>()
#      20
#      21 while True:
# ---> 22     user_input = input("You: ")
#      23     response = chatbot.generate_response(user_input)
#      24     print("Chatbot:", response)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
# !pip install fuzzywuzzy

# %%
# !pip install python-Levenshtein
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 55.4 MB/s eta 0:00:00
# ...

# %%
import random
from fuzzywuzzy import fuzz

class Chatbot:
    def __init__(self):
        self.responses = ["Hello!", "Great! How are you?", "What can I do for you?",
                          "Nice to meet you!", "I'm here to assist you.",
                          "Feeling good today!", "How can I help you?",
                          "Greetings!", "Pleasure to interact with you."]

    def generate_response(self, user_input):
        best_match = None
        best_score = 0
        for response in self.responses:
            score = fuzz.ratio(user_input, response)
            if score > best_score:
                best_match = response
                best_score = score

        return best_match

chatbot = Chatbot()

while True:
    user_input = input("You: ")
    response = chatbot.generate_response(user_input)
    print("Chatbot:", response)
# Out:
# You: Hi
# Chatbot: Hello!
# You: How are you?
# Chatbot: Great! How are you?
# You: I'm good
# Chatbot: I'm here to assist you.
# You: Thank you.
# Chatbot: What can I do for you?

# %%
import random
from fuzzywuzzy import fuzz

class Chatbot:
    def __init__(self, dataset_path):
        with open(dataset_path, "r") as file:
            self.responses = [line.strip() for line in file]

    def generate_response(self, user_input):
        best_match = None
        best_score = 0
        for response in self.responses:
            score = fuzz.ratio(user_input, response)
            if score > best_score:
                best_match = response
                best_score = score

        return best_match

# Provide the path to your dataset
dataset_path = "/content/dialogs.txt"
chatbot = Chatbot(dataset_path)

while True:
    user_input = input("You: ")
    response = chatbot.generate_response(user_input)
    print("Chatbot:", response)
# Out:
# You: hi
# Chatbot: doing what?	working.
# You: Hello
# Chatbot: i love baseball.	so do i.
# You: How are you?
# Chatbot: no.	how do you know?
# You: tell me a joke
# Chatbot: tell me you're joking.	i love that show.
# You: i'm in college
# Chatbot: i hate homework.	are you going to college?
# You: here already
# Chatbot: heard what?	debrah already had her baby.
# You: joke
# Chatbot: look at this sheet.	yes?
# You: pretty
# Chatbot: put your seatbelt on.	why?
# You: um
# Chatbot: excuse me.	yes?
# You: haha
# Chatbot: i did.	what happened?
# You: you're funny
# Chatbot: put your seatbelt on.	why?
# You: stop
# Chatbot: sure.	thank you.
# You: i'm sleepy
# Chatbot: i'm sleepy.	so am i.
# You: that is great
# Chatbot: eight o'clock.	that sounds great.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-737fadae4044> in <cell line: 25>()
#      24
# ...

# %%
import random
from fuzzywuzzy import fuzz

class Chatbot:
    def __init__(self, dataset_path):
        with open(dataset_path, "r") as file:
            self.responses = [line.strip() for line in file]

    def generate_response(self, user_input):
        best_match = None
        best_score = 0
        for response in self.responses:
            score = fuzz.ratio(user_input, response)
            if score > best_score:
                best_match = response
                best_score = score

        return best_match

# Provide the path to your dataset
dataset_path = "/content/Conversation.csv"
chatbot = Chatbot(dataset_path)

while True:
    user_input = input("You: ")
    response = chatbot.generate_response(user_input)
    print("Chatbot:", response)
# Out:
# You: hi, how are you doing?
# Chatbot: 0,"hi, how are you doing?",i'm fine. how about yourself?
# You: i've actually been pretty good. you?
# Chatbot: 14,so how have you been lately?,i've actually been pretty good. you?
# You: it doesn't look very nice outside today.
# Chatbot: 43,it doesn't look very nice outside today.,you're right. i think it's going to rain later.
# You: it's the middle of summer, it shouldn't rain today.
# Chatbot: 34,"it's the middle of summer, it shouldn't rain today.",that would be weird.
# You: why is that?
# Chatbot: 618,probably not.,why is that?
# You: i was thinking about seeing a movie.
# Chatbot: 147,i was thinking about seeing a movie.,"okay, let's go see a movie."
# You: have you met the new girl?
# Chatbot: 182,have you met the new girl?,no. have you?
# You: i was sick.
# Chatbot: 202,i was sick.,how were you sick?
# You: well, i think you look nice today too.
# Chatbot: 274,i love your outfit right now.,"well, i think you look nice today too."
# ...
